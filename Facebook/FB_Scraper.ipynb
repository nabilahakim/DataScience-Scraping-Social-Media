# %%
# !pip install facebook_scraper
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 KB 1.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.3/293.3 KB 9.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.5/131.5 KB 8.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 KB 3.7 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.4/83.4 KB 5.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.0/107.0 KB 4.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 KB 6.6 MB/s eta 0:00:00
# ...
#   Created wheel for demjson3: filename=demjson3-3.0.6-py3-none-any.whl size=75309 sha256=f042a7e097387af963de7eb94247dff21c78226ea8974763e87c33a8efb53c44
# ...

# %%
from facebook_scraper import get_posts
import pandas as pd
from datetime import datetime, timezone
from itertools import dropwhile, takewhile

# %%
post_df_full = pd.DataFrame(columns = [])
#SINCE = datetime(2019, 1, 1)
#UNTIL = datetime(2019, 12, 31)

# %%
#filters = ['since:2019-01-01', 'until:2019-12-31']
#from_filters = []
#if (lambda p: p.date >= SINCE, dropwhile(lambda p: p.date > UNTIL, post_df_full)):
for post in get_posts('CNNIndonesia',
                          #post_urls='https://web.facebook.com/search/posts?q=2019gantipresiden', 
                          #credentials=('email', 'password'),
                          cookies='/content/all_cookies.txt',
                          extra_info=True, 
                          page_limit= 20, 
                          options={"comments_full": True}):
      post_entry = post
      fb_post_df = pd.DataFrame.from_dict(post_entry, orient='index')
      fb_post_df = fb_post_df.transpose()
      post_df_full = post_df_full.append(fb_post_df)


    #from_filters.append(f'from:{post}')
    #filters.append(' OR '.join(from_filters))
      print(post['comments_full'] +' get')

# %%
post_df_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 153 entries, 0 to 0
# Data columns (total 55 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   original_request_url           153 non-null    object
#  1   post_url                       153 non-null    object
#  2   post_id                        89 non-null     object
#  3   text                           89 non-null     object
#  4   post_text                      89 non-null     object
#  5   shared_text                    58 non-null     object
#  6   original_text                  0 non-null      object
#  7   time                           89 non-null     datetime64[ns]
#  8   timestamp                      30 non-null     object
#  9   image                          29 non-null     object
#  10  image_lowquality               80 non-null     object
#  11  images                         89 non-null     object
# ...

# %%
post_df_full
# Out:
#    original_request_url                                           post_url  \
# 0                     h                           https://m.facebook.com/h
# 0                     h                           https://m.facebook.com/h
# 0                     h                           https://m.facebook.com/h
# 0                     h                           https://m.facebook.com/h
# 0                     h                           https://m.facebook.com/h
# ..                  ...                                                ...
# 0                     s  https://facebook.com/story.php?story_fbid=pfbi...
# 0                     i  https://facebook.com/story.php?story_fbid=pfbi...
# 0                     d  https://facebook.com/story.php?story_fbid=1020...
# 0                     e  https://facebook.com/story.php?story_fbid=1015...
# 0                     n  https://facebook.com/story.php?story_fbid=pfbi...
#
#                                               post_id  \
# ...

# %%
post_df_full.to_csv(r'fb_CNN.csv', index = False)

# %%
import pandas as pd
df1 =pd.read_csv('fb_CNN.csv')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1091 entries, 0 to 1090
# Data columns (total 57 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   post_id                        1091 non-null   int64
#  1   text                           1022 non-null   object
#  2   post_text                      990 non-null    object
#  3   shared_text                    269 non-null    object
#  4   original_text                  13 non-null     object
#  5   time                           1090 non-null   object
#  6   timestamp                      91 non-null     float64
#  7   image                          649 non-null    object
#  8   image_lowquality               1038 non-null   object
#  9   images                         1087 non-null   object
#  10  images_description             1087 non-null   object
#  11  images_lowquality              1091 non-null   object
# ...

# %%
komen = df1["comments_full"].tolist()

# %%
with open("parsed_data.csv", "w") as file:
writer = csv.writer(file)
# Write the contents of the "Name" column into the new CSV file
for name in names:
writer.writerow([komentar])

# %%
dicti = (print(post_df_full1['comments_full'].iloc[5:6].values))
# Out:
# ["[{'comment_id': '801298397754293', 'comment_url': 'https://facebook.com/801298397754293', 'commenter_id': '1099062679', 'commenter_url': 'https://facebook.com/ibnuyahya?eav=Afa80PhU3vrdv23ow268CaJtBawqmgDlxwE57u0yCFohNu1p0crSi596d3dxxkfmn6A&fref=nf&refid=52&__tn__=R&paipv=0', 'commenter_name': 'T Ahmad Danial', 'commenter_meta': None, 'comment_text': 'wuih, sukses dan melejit pak channelnya :)', 'comment_time': datetime.datetime(2022, 9, 23, 0, 0), 'comment_image': 'https://scontent-ord5-1.xx.fbcdn.net/m1/v/t6/An_UvxJXg9tdnLU3Y5qjPi0200MLilhzPXUgxzGjQzUMaNcmjdZA6anyrngvkdub33NZzZhd51fpCAEzNHFhko5aKRFP5fS1w_lKwYrzcNLupv27.png?_nc_eui2=AeEMDnQjwHe-67SZWQ4g8Ak9MiCX3WNpzi0yIJfdY2nOLVjBgR8sv442wdnPhl-8vXlObU8qbaMZZeM9YWgGhUhA&ccb=10-5&oh=00_AfBG9JsfSHqXB1MjciP8xmSlWfF12v1JPZOSB-N1MEisSg&oe=63A5D379&_nc_sid=55e238', 'comment_reactors': [{'name': 'Prabowo Boedianto', 'link': 'https://facebook.com/prabowo?eav=Afb_5dwUXeYWoWIfoaXoS1cHwBqq-BnZBHxrISXHb0e8Pabe0OUVLcSYPpYOdDY81Kc&fref=pb&paipv
# ...

# %%
import numpy as np
columns = list(dicti.keys())
values = list(dicti.values())
arr_len = len(values)

pd.DataFrame(np.array(values, dtype=object).reshape(1, arr_len), columns=columns)

# %%
#df1= pd.DataFrame([dicti.keys(), dicti.values()]).T
'pd.DataFrame(dicti.items), columns= ['comment_id', 
                                      'comment_url', 
                                      'commenter_id', 
                                     'commenter_url', 
                                      'commenter_name', 
                                         'commenter_meta', 
                                   'comment_text', 
                                    'comment_time', 
                                     'comment_image', 
                                      'comment_reactors', 
                                      'comment_reactions',
                                      'comment_reaction_count',
                                                'replies']'
